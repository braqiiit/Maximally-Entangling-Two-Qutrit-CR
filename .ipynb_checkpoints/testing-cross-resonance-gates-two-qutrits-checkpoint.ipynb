# %%
# Configure JAX
import jax
jax.config.update("jax_enable_x64", True)
jax.config.update("jax_platform_name", "cpu")

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import numpy as np

from qiskit import *

import matplotlib.pyplot as plt

from qiskit.quantum_info import Statevector

# %%
freq_0 = 4.9e9
amp_0 = 0.059501279242309815
beta_0 =-0.9899497487437185
ef_freq_0 = 4.5e9
ef_amp_0 = 0.04091261035812275
ef_beta_0 = -0.015075376884422287

freq_1 = 5.5e9
amp_1 = 0.05039825490571683
beta_1 = -2.8282828282828283
ef_freq_1 = 5.2e9
ef_amp_1 = 0.03587788534159534
ef_beta_1 = -2.8282828282828283

# %%
import numpy as np
from qiskit import pulse
from qiskit_dynamics import Solver, DynamicsBackend 
from qiskit.circuit.library import XGate, SXGate, RZGate, CXGate, HGate
from qiskit.circuit import Parameter, Gate
from qiskit.providers.backend import QubitProperties
from qiskit.transpiler import InstructionProperties
from qiskit.providers.models import PulseDefaults


class TwoQutritPulseSimulator():
    def __init__(
        self,
        qubit_frequency_0 = 4.9e9,
        qubit_frequency_1 = 5.5e9,
        anharmonicity_0 = -0.4e9,
        anharmonicity_1 = -0.3e9,
        drive_strength_0 = 0.22e9,
        drive_strength_1 = 0.26e9,
    ):
        dim = 3

        self.v0 = qubit_frequency_0
        self.anharmon_0 = anharmonicity_0
        self.r0 = drive_strength_0
        
        self.v1 = qubit_frequency_1
        self.anharmon_1 = anharmonicity_1
        self.r1 = drive_strength_1
        
        self.J = 2.7e6
        
        a = np.diag(np.sqrt(np.arange(1, dim)), 1)
        adag = np.diag(np.sqrt(np.arange(1, dim)), -1)
        N = np.diag(np.arange(dim))
        
        ident = np.eye(dim, dtype=complex)
        full_ident = np.eye(dim**2, dtype=complex)
        
        N0 = np.kron(ident, N)
        N1 = np.kron(N, ident)
        
        a0 = np.kron(ident, a)
        a1 = np.kron(a, ident)
        
        a0dag = np.kron(ident, adag)
        a1dag = np.kron(adag, ident)
        
        
        static_ham0 = 2 * np.pi * self.v0 * N0 + np.pi * self.anharmon_0 * N0 * (N0 - full_ident)
        static_ham1 = 2 * np.pi * self.v1 * N1 + np.pi * self.anharmon_1 * N1 * (N1 - full_ident)
        
        static_ham_full = static_ham0 + static_ham1 + 2 * np.pi * self.J * ((a0 + a0dag) @ (a1 + a1dag))
        
        drive_op0 = 2 * np.pi * self.r0 * (a0 + a0dag)
        drive_op1 = 2 * np.pi * self.r1 * (a1 + a1dag)

        # build solver
        dt = 1/4.5e9
        
        self.solver = Solver(
            static_hamiltonian=static_ham_full,
            hamiltonian_operators=[drive_op0, drive_op1, drive_op0, drive_op1],
            # rotating_frame=static_ham_full,
            hamiltonian_channels=["d0", "d1", "u0", "u1"],
            channel_carrier_freqs={"d0": self.v0, "d1": self.v1, "u0": self.v1, "u1": self.v0},
            dt=dt,
            array_library="jax",
        )

        # Consistent solver option to use throughout notebook
        solver_options = {"method": "jax_odeint", "atol": 1e-10, "rtol": 1e-10, "hmax": dt}
        
        self.backend = DynamicsBackend(
            solver=self.solver,
            subsystem_dims=[dim, dim], # for computing measurement data
            solver_options=solver_options, # to be used every time run is called
            max_outcome_level=dim,
        )

        # self.backend.set_options(
        #     defaults = PulseDefaults.from_dict(
        #         {
        #             "qubit_freq_est": [self.v0, self.v1],
        #             "meas_freq_est": [0, 0],
        #             "buffer": 0,
        #             "pulse_library": [],
        #             "cmd_def":[]
        #         }
        #     )
        # )

        self.target = self.backend.target

        # qubit properties
        self.target.qubit_properties = [QubitProperties(frequency=self.v0), QubitProperties(frequency=self.v1)]
        
        #####################################################################################
        ##### add instructions for qutrits #####

        x01_gate = Gate('x01', 1, [])
        
        with pulse.build() as x01_0:
            pulse.Play(pulse.Gaussian(320, 0.5, 80), pulse.DriveChannel(0))
        
        with pulse.build() as x01_1:
            pulse.Play(pulse.Gaussian(320, 0.5, 80), pulse.DriveChannel(1))

        self.target.add_instruction(
            x01_gate,
            {
                (0,): InstructionProperties(calibration=x01_0), 
                (1,): InstructionProperties(calibration=x01_1)
            }
        )
        
        # self.target.add_instruction(XGate(), properties={(0,): None, (1,): None})
        # self.target.add_instruction(SXGate(), properties={(0,): None, (1,): None})
        
        self.target.add_instruction(CXGate(), properties={(0, 1): None, (1, 0): None})
        
        #### Add RZ instruction as phase shift for drag cal  #####
        phi = Parameter("phi")
        with pulse.build() as rz0:
            pulse.shift_phase(phi, pulse.DriveChannel(0))
            pulse.shift_phase(phi, pulse.ControlChannel(1))
        
        with pulse.build() as rz1:
            pulse.shift_phase(phi, pulse.DriveChannel(1))
            pulse.shift_phase(phi, pulse.ControlChannel(0))
        
        self.target.add_instruction(
            RZGate(phi),
            {(0,): InstructionProperties(calibration=rz0), (1,): InstructionProperties(calibration=rz1)}
        )

        ##################################################################################

        self.backend.set_options(control_channel_map={(0, 1): 0, (1, 0): 1})

    def get_backend(self):
        return self.backend

    def get_solver(self):
        return self.solver

    def get_target(self):
        return self.target

# %%
sim = TwoQutritPulseSimulator()
target = sim.get_target()
backend = sim.get_backend()
# Out:
# WARNING:2025-04-14 09:05:14,480:jax._src.xla_bridge:966: An NVIDIA GPU may be present on this machine, but a CUDA-enabled jaxlib is not installed. Falling back to cpu.

# %%
dchan0 = pulse.DriveChannel(0)
dchan1 = pulse.DriveChannel(1)

uchan0 = pulse.ControlChannel(0)
uchan1 = pulse.ControlChannel(1)

achan0 = pulse.AcquireChannel(0)
achan1 = pulse.AcquireChannel(1)

memslot = pulse.MemorySlot(0)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 0 and 1 evolves over time when the control is 0 and the cr frequency is freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 320
        
        pulse.set_frequency(freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, 0.8*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_0 = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_evolve_jobs_0.append(cr_job)
# Out:
# state, dur =  100
# state, dur =  500
# state, dur =  1000
# state, dur =  1500

# %%
pop_values = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, res in enumerate(cr_evolve_jobs_0):
    for i in basis_states:
        if i in res.result().get_counts():
            pop_values[int(i, 3)].append(res.result().get_counts()[i]/1024)
        else:
            pop_values[int(i, 3)].append(0)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 0 and 1 evolves over time when the control is 1 and the cr frequency is freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 320
        
        pulse.set_frequency(freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, 0.8*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_1 = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_evolve_jobs_1.append(cr_job)
# Out:
# state, dur =  100
# state, dur =  500
# state, dur =  1000
# state, dur =  1500

# %%
pop_values_1 = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, res in enumerate(cr_evolve_jobs_1):
    for i in basis_states:
        if i in res.result().get_counts():
            pop_values_1[int(i, 3)].append(res.result().get_counts()[i]/1024)
        else:
            pop_values_1[int(i, 3)].append(0)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_1[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 0 and 1 evolves over time when the control is 2 and the cr frequency is freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        pulse.set_frequency(ef_freq_0, dchan0)
        pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 640
        
        pulse.set_frequency(freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, 0.8*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_2 = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_evolve_jobs_2.append(cr_job)
# Out:
# state, dur =  100
# state, dur =  500
# state, dur =  1000
# state, dur =  1500

# %%
pop_values_2 = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, res in enumerate(cr_evolve_jobs_2):
    for i in basis_states:
        if i in res.result().get_counts():
            pop_values_2[int(i, 3)].append(res.result().get_counts()[i]/1024)
        else:
            pop_values_2[int(i, 3)].append(0)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_2[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 1 and 2 evolves over time when the control is 0 and the cr frequency is ef_freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 640
        
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 1, 76, 0.9*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_0_ef = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})
    t_span = [0., 640+int(dur)]
    y0 = Statevector([1,0,0,0,0,0,0,0,0])

#     cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job = backend.solve(cr_pulse, t_span=t_span, y0=y0)
    cr_evolve_jobs_0_ef.append(cr_job)
# Out:
# state, dur =  100

# %%
# pop_values_0_ef = [[] for i in range(9)]
# basis_states = ['00','01','02','10','11','12','20','21','22']

# for j, res in enumerate(cr_evolve_jobs_0_ef):
#     for i in basis_states:
#         if i in res.result().get_counts():
#             pop_values_0_ef[int(i, 3)].append(res.result().get_counts()[i]/1024)
#         else:
#             pop_values_0_ef[int(i, 3)].append(0)

# %%
for j, job in enumerate(cr_evolve_jobs_0_ef):
    print(job.result().data)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_0_ef[i])
plt.legend(basis_states)

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_0_ef[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 0 and 1 evolves over time when the control is 1 and the cr frequency is ef_freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 640
        
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 0.8, 76, 0.8*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_1_ef = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_evolve_jobs_1_ef.append(cr_job)
# Out:
# state, dur =  100
# state, dur =  500
# state, dur =  1000
# state, dur =  1500

# %%
pop_values_1_ef = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, res in enumerate(cr_evolve_jobs_1_ef):
    for i in basis_states:
        if i in res.result().get_counts():
            pop_values_1_ef[int(i, 3)].append(res.result().get_counts()[i]/1024)
        else:
            pop_values_1_ef[int(i, 3)].append(0)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_1_ef[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state of equal superposition of 0 and 1 evolves over time when the control is 2 and the cr frequency is ef_freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    with pulse.build(name="cr_0") as cr_pulse:        
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        pulse.set_frequency(ef_freq_0, dchan0)
        pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        delay_time = 640
        
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 0.8, 76, 0.8*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(delay_time + dur, achan0)
        pulse.delay(delay_time + dur, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_evolve_jobs_2_ef = []

for dur in np.arange(min_duration, max_duration, step_size):
    if dur %500 == 0 or dur==100:
        print('state, dur = ', dur)
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_evolve_jobs_2_ef.append(cr_job)
# Out:
# state, dur =  100
# state, dur =  500
# state, dur =  1000
# state, dur =  1500

# %%
pop_values_2_ef = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, res in enumerate(cr_evolve_jobs_2_ef):
    for i in basis_states:
        if i in res.result().get_counts():
            pop_values_2_ef[int(i, 3)].append(res.result().get_counts()[i]/1024)
        else:
            pop_values_2_ef[int(i, 3)].append(0)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pop_values_2_ef[i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state evolves over time for different control and target states when cr_freq = freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse(init_state, cr_drive_freq):
    ctrl, target = init_state
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        if ctrl == '1' or ctrl == '2':
            pulse.set_frequency(freq_0, dchan0)
            pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        if ctrl == '2':
            pulse.set_frequency(ef_freq_0, dchan0)
            pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        if target == '1' or target == '2':
            pulse.set_frequency(freq_1, dchan1)
            pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        if target == '2':
            pulse.set_frequency(ef_freq_1, dchan1)
            pulse.play(pulse.Drag(320, ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        if ctrl == '2' or target == '2':
            delay_time = 640
        elif ctrl == '1' or target == '1':
            delay_time = 320
        else:
            delay_time = 0
        
        pulse.set_frequency(cr_drive_freq, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, 0.841*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

pop_characterization_jobs = [[] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for i, state in enumerate(basis_states):
    for dur in np.arange(min_duration, max_duration, step_size):
        if dur %500 == 0 or dur==100:
            print('state, dur = ', state, dur)
        cr_pulse = get_cr_pulse(state, freq_1)

        cr_pulse.assign_parameters({'duration': int(dur)})

        cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
        pop_characterization_jobs[i].append(cr_job)
# Out:
# state, dur =  00 100
# state, dur =  00 500
# state, dur =  00 1000
# state, dur =  00 1500
# state, dur =  01 100
# state, dur =  01 500
# state, dur =  01 1000
# state, dur =  01 1500
# state, dur =  02 100
# state, dur =  02 500
# state, dur =  02 1000
# state, dur =  02 1500
# state, dur =  10 100
# state, dur =  10 500
# state, dur =  10 1000
# state, dur =  10 1500
# state, dur =  11 100
# state, dur =  11 500
# state, dur =  11 1000
# state, dur =  11 1500
# state, dur =  12 100
# state, dur =  12 500
# state, dur =  12 1000
# state, dur =  12 1500
# state, dur =  20 100
# state, dur =  20 500
# state, dur =  20 1000
# state, dur =  20 1500
# state, dur =  21 100
# state, dur =  21 500
# state, dur =  21 1000
# state, dur =  21 1500
# state, dur =  22 100
# state, dur =  22 500
# state, dur =  22 1000
# state, dur =  22 1500

# %%
pop_values = [[[] for i in range(9)] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, item in enumerate(pop_characterization_jobs):
    for res in item:
        for i in basis_states:
            if i in res.result().get_counts():
                pop_values[j][int(i, 3)].append(res.result().get_counts()[i]/1024)
            else:
                pop_values[j][int(i, 3)].append(0)

# %%
import pickle

with open("pop_values_freq_1.pkl", "wb") as f:
    pickle.dump(pop_values, f)

# %%
import pickle

with open('pop_values_freq_1.pkl','rb') as f: 
    pickled_pop_values = pickle.load(f)

# %%
dur_list[18]
# Out:
# np.int64(1000)

# %%
print(dur_list[np.where(pickled_pop_values[0][0] == np.array([min(pickled_pop_values[0][0])]))])
print(dur_list[np.where(pickled_pop_values[6][6] == np.array([min(pickled_pop_values[6][6])]))])
# Out:
# [1400]
# [1250]

# %%
min_duration = 100
max_duration = 2000
step_size = 50

dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pickled_pop_values[1][i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking how to initial state evolves over time for different control and target states when cr_freq = ef_freq_1

# %%
min_duration = 100
max_duration = 2000
step_size = 50

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse(init_state, cr_drive_freq):
    ctrl, target = init_state
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        if ctrl == '1' or ctrl == '2':
            pulse.set_frequency(freq_0, dchan0)
            pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        if ctrl == '2':
            pulse.set_frequency(ef_freq_0, dchan0)
            pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        if target == '1' or target == '2':
            pulse.set_frequency(freq_1, dchan1)
            pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        if target == '2':
            pulse.set_frequency(ef_freq_1, dchan1)
            pulse.play(pulse.Drag(320, ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        if ctrl == '2' or target == '2':
            delay_time = 640
        elif ctrl == '1' or target == '1':
            delay_time = 320
        else:
            delay_time = 0
        
        pulse.set_frequency(cr_drive_freq, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, 0.95*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

pop_characterization_jobs_ef = [[] for i in range(9)]
# basis_states = ['00','01','02','10','11','12','20','21','22']
basis_states = ['01', '21']

for i, state in enumerate(basis_states):
    for dur in np.arange(min_duration, max_duration, step_size):
        if dur %500 == 0 or dur==100:
            print('state, dur = ', state, dur)
        cr_pulse = get_cr_pulse(state, ef_freq_1)

        cr_pulse.assign_parameters({'duration': int(dur)})

        cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
        pop_characterization_jobs_ef[i].append(cr_job)
# Out:
# state, dur =  01 100
# state, dur =  01 500
# state, dur =  01 1000
# state, dur =  01 1500
# state, dur =  21 100
# state, dur =  21 500
# state, dur =  21 1000
# state, dur =  21 1500

# %%
pop_values_ef = [[[] for i in range(9)] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, item in enumerate(pop_characterization_jobs_ef[:2]):
    for res in item:
        for i in basis_states:
            if i in res.result().get_counts():
                pop_values_ef[j][int(i, 3)].append(res.result().get_counts()[i]/1024)
            else:
                pop_values_ef[j][int(i, 3)].append(0)

# %%
# import pickle

# with open("pop_values_ef_freq_1.pkl", "wb") as f:
#     pickle.dump(pop_values_ef, f)

# %%
# with open('pop_values_ef_freq_1.pkl','rb') as f: 
#     pickled_pop_values_ef = pickle.load(f)

# %%
pickled_pop_values_ef = pop_values_ef

# %%
dur_list[np.where(pickled_pop_values_ef[0][2] == np.array([min(pickled_pop_values_ef[0][2][:30])]))]
# Out:
# array([1150])

# %%
dur_list[np.where(pickled_pop_values_ef[1][8] == np.array([min(pickled_pop_values_ef[1][8][:30])]))]
# Out:
# array([1250])

# %% [markdown]
# When width=0.65, amp = 2, the min values occur at 650 and 700. LCM = 9100
#
# When width=0.9, amp = 2, the min values occur at 550 and 650. LCM = 7150
#
# When width=0.9, amp = 4, the min values occur at 425 and 450. LCM = 7650. There are some stray probabilities in this config.
#
# When width=0.95, amp = 2, the min values occur at 575 and 625. LCM = 14375. There are some stray probabilities in this config.

# %%
dur_list = np.arange(min_duration, max_duration, step_size)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(dur_list, pickled_pop_values_ef[0][i])
plt.legend(basis_states)

# %% [markdown]
# ### Checking the influence of width

# %%
min_width = 0.1
max_width = 0.99
step_size = 0.01

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse(init_state, width):
    ctrl, target = init_state
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        if ctrl == '1' or ctrl == '2':
            pulse.set_frequency(freq_0, dchan0)
            pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        if ctrl == '2':
            pulse.set_frequency(ef_freq_0, dchan0)
            pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        if target == '1' or target == '2':
            pulse.set_frequency(freq_1, dchan1)
            pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        if target == '2':
            pulse.set_frequency(ef_freq_1, dchan1)
            pulse.play(pulse.Drag(320, ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        if ctrl == '2' or target == '2':
            delay_time = 640
        elif ctrl == '1' or target == '1':
            delay_time = 320
        else:
            delay_time = 0
        
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 2, 76, width*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

pop_jobs_width_sweep = [[] for i in range(9)]
# basis_states = ['00','01','02','10','11','12','20','21','22']
basis_states = ['01', '21']
dur = 600

for i, state in enumerate(basis_states):
    for j, width in enumerate(np.arange(min_width, max_width, step_size)):
        if j%10 == 0:
            print('state, width', state, width)
        cr_pulse = get_cr_pulse(state, width)

        cr_pulse.assign_parameters({'duration': int(dur)})

        cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
        pop_jobs_width_sweep[i].append(cr_job)
# Out:
# state, width 01 0.1
# state, width 01 0.19999999999999996
# state, width 01 0.29999999999999993
# state, width 01 0.3999999999999998
# state, width 01 0.4999999999999998
# state, width 01 0.5999999999999998
# state, width 01 0.6999999999999996
# state, width 01 0.7999999999999996
# state, width 01 0.8999999999999996
# state, width 21 0.1
# state, width 21 0.19999999999999996
# state, width 21 0.29999999999999993
# state, width 21 0.3999999999999998
# state, width 21 0.4999999999999998
# state, width 21 0.5999999999999998
# state, width 21 0.6999999999999996
# state, width 21 0.7999999999999996
# state, width 21 0.8999999999999996

# %%
pop_values_width_sweep = [[[] for i in range(9)] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, item in enumerate(pop_jobs_width_sweep[:2]):
    for res in item:
        for i in basis_states:
            if i in res.result().get_counts():
                pop_values_width_sweep[j][int(i, 3)].append(res.result().get_counts()[i]/1024)
            else:
                pop_values_width_sweep[j][int(i, 3)].append(0)

# %%
len(width_list)
# Out:
# 1

# %%
width_list = np.arange(0.1, 0.99, 0.01)
basis_states = ['00','01','02','10','11','12','20','21','22']

plt.figure(figsize=(13,7))
for i in range(9):
    plt.plot(width_list, pop_values_width_sweep[0][i])
plt.legend(basis_states)

# %%
for width, val in zip(width_list, pop_values_width_sweep[0][1]):
    print(width, val)
# Out:
# 0.1 0.509765625
# 0.11 0.505859375
# 0.12 0.478515625
# 0.13 0.498046875
# 0.13999999999999999 0.4638671875
# 0.14999999999999997 0.443359375
# 0.15999999999999998 0.435546875
# 0.16999999999999998 0.4091796875
# 0.17999999999999997 0.43359375
# 0.18999999999999995 0.3759765625
# 0.19999999999999996 0.3779296875
# 0.20999999999999996 0.3369140625
# 0.21999999999999995 0.3310546875
# 0.22999999999999995 0.3154296875
# 0.23999999999999994 0.3056640625
# 0.24999999999999992 0.28125
# 0.2599999999999999 0.275390625
# 0.2699999999999999 0.259765625
# 0.2799999999999999 0.26171875
# 0.2899999999999999 0.2529296875
# 0.29999999999999993 0.22265625
# 0.30999999999999994 0.2041015625
# 0.3199999999999999 0.2255859375
# 0.32999999999999985 0.1787109375
# 0.33999999999999986 0.17578125
# 0.34999999999999987 0.1474609375
# 0.3599999999999999 0.1650390625
# 0.3699999999999999 0.1396484375
# 0.3799999999999999 0.1298828125
# 0.3899999999999999 0.1240234375
# 0.3999999999999998 0.134765625
# 0.4099999999999998 0.1220703125
# 0.4199999999999998 0.1015625
# 0.4299999999999998 0.1083984375
# 0.43999999999999984 0.0771484375
# 0.44999999999999984 0.078125
# 0.45999999999999985 0.078125
# 0.46999999999999986 0.0693359375
# 0.47999999999999976 0.05859375
# 0.48999999999999977 0.052734375
# 0.4999999999999998 0.05078125
# 0.5099999999999998 0.0537109375
# 0.5199999999999998 0.04296875
# 0.5299999999999998 0.044921875
# 0.5399999999999998 0.025390625
# 0.5499999999999998 0.033203125
# 0.5599999999999997 0.025390625
# 0.5699999999999997 0.03515625
# 0.5799999999999997 0.0185546875
# 0.5899999999999997 0.009765625
# 0.5999999999999998 0.0244140625
# 0.6099999999999998 0.01953125
# 0.6199999999999998 0.0068359375
# 0.6299999999999997 0.0029296875
# 0.6399999999999997 0.0107421875
# 0.6499999999999997 0.005859375
# 0.6599999999999997 0.009765625
# 0.6699999999999997 0.005859375
# 0.6799999999999997 0.00390625
# 0.6899999999999997 0.0078125
# 0.6999999999999996 0.0009765625
# 0.7099999999999996 0.001953125
# 0.7199999999999996 0.0009765625
# 0.7299999999999996 0.001953125
# 0.7399999999999997 0.0009765625
# 0.7499999999999997 0.0009765625
# 0.7599999999999997 0.0009765625
# 0.7699999999999997 0
# 0.7799999999999997 0
# 0.7899999999999996 0.001953125
# 0.7999999999999996 0
# 0.8099999999999996 0.0009765625
# 0.8199999999999996 0.0009765625
# 0.8299999999999996 0.0009765625
# 0.8399999999999996 0
# 0.8499999999999996 0.0029296875
# 0.8599999999999995 0.0029296875
# 0.8699999999999996 0.005859375
# 0.8799999999999996 0.0029296875
# 0.8899999999999996 0.0048828125
# 0.8999999999999996 0.00390625
# 0.9099999999999996 0.009765625
# 0.9199999999999996 0.00390625
# 0.9299999999999996 0.0009765625
# 0.9399999999999996 0.0009765625
# 0.9499999999999995 0
# 0.9599999999999995 0.0087890625
# 0.9699999999999995 0.025390625
# 0.9799999999999995 0.0625

# %%
min_freq = 0.8*ef_freq_1
max_freq = 1.2*freq_1
steps = 100

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse(init_state, cr_drive_freq):
    ctrl, target = init_state
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        if ctrl == '1' or ctrl == '2':
            pulse.set_frequency(freq_0, dchan0)
            pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        if ctrl == '2':
            pulse.set_frequency(ef_freq_0, dchan0)
            pulse.play(pulse.Drag(320, ef_amp_0, 80, ef_beta_0, limit_amplitude=False), dchan0)
        
        if target == '1' or target == '2':
            pulse.set_frequency(freq_1, dchan1)
            pulse.play(pulse.Drag(320, amp_1, 80, beta_1, limit_amplitude=False), dchan1)
        if target == '2':
            pulse.set_frequency(ef_freq_1, dchan1)
            pulse.play(pulse.Drag(320, ef_amp_1, 80, ef_beta_1, limit_amplitude=False), dchan1)
        
        if ctrl == '2' or target == '2':
            delay_time = 640
        elif ctrl == '1' or target == '1':
            delay_time = 320
        else:
            delay_time = 0
        
        pulse.set_frequency(cr_drive_freq, uchan0)
        pulse.delay(delay_time, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 0.5, 76, 0.841*dur, limit_amplitude=False), uchan0)
        
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

freq_absorb_jobs_ef = []
basis_states = ['00','01','02','10','11','12','20','21','22']

state = '01'
dur = 1000
for i, freq in enumerate(np.arange(min_freq, max_freq, step_size)):
    if i%10 == 0:
        print(freq)
    cr_pulse = get_cr_pulse(state, freq)

    cr_pulse.assign_parameters({'duration': int(dur)})

    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    freq_absorb_jobs_ef.append(cr_job)
# Out:
# 0.028702308273276272
# 500.0287023082733
# 1000.0287023082733
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[33], line 57
#      53 cr_pulse = get_cr_pulse(state, freq)
#      55 cr_pulse.assign_parameters({'duration': int(dur)})
# ---> 57 cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
#      58 freq_absorb_jobs_ef.append(cr_job)
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/qiskit_dynamics/backend/dynamics_backend.py:452, in DynamicsBackend.run(self, run_input, validate, **options)
#     439 job_id = str(uuid.uuid4())
#     440 dynamics_job = DynamicsJob(
#     441     backend=backend,
#     442     job_id=job_id,
#    (...)
#     450     },
#     451 )
# --> 452 dynamics_job.submit()
#     454 return dynamics_job
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/qiskit_dynamics/backend/dynamics_job.py:54, in DynamicsJob.submit(self)
#      52 if self._result is not None:
#      53     raise JobError("Dynamics job has already been submitted.")
# ---> 54 self._result = self._fn(job_id=self.job_id(), **self._fn_kwargs)
#      55 self._time_per_step["COMPLETED"] = datetime.now()
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/qiskit_dynamics/backend/dynamics_backend.py:472, in DynamicsBackend._run(self, job_id, t_span, schedules, measurement_subsystems_list, memory_slot_indices_list, num_memory_slots_list)
#     469 if y0 == "ground_state":
#     470     y0 = Statevector(self._dressed_states[:, 0])
# --> 472 solver_results = self.options.solver.solve(
#     473     t_span=t_span, y0=y0, signals=schedules, **self.options.solver_options
#     474 )
#     476 # compute results for each experiment
#     477 experiment_names = [schedule.name for schedule in schedules]
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/qiskit_dynamics/solvers/solver_classes.py:532, in Solver.solve(self, t_span, y0, signals, convert_results, **kwargs)
#     524     if self.model.array_library not in ["numpy", "jax", "jax_sparse"]:
#     525         warn(
#     526             "Attempting to internally JAX-compile simulation of schedules, with "
#     527             'Solver.model.array_library not in ["numpy", "jax", "jax_sparse"]. If an error '
#     528             "is not raised, explicitly set array_library at Solver instantation to one of "
#     529             "these options to remove this warning."
#     530         )
# --> 532     all_results = self._solve_schedule_list_jax(
#     533         t_span_list=t_span_list,
#     534         y0_list=y0_list,
#     535         schedule_list=signals_list,
#     536         convert_results=convert_results,
#     537         **kwargs,
#     538     )
#     539 else:
#     540     all_results = self._solve_list(
#     541         t_span_list=t_span_list,
#     542         y0_list=y0_list,
#    (...)
#     545         **kwargs,
#     546     )
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/qiskit_dynamics/solvers/solver_classes.py:662, in Solver._solve_schedule_list_jax(self, t_span_list, y0_list, schedule_list, convert_results, **kwargs)
#     659 for idx, sig in enumerate(all_signals):
#     660     all_samples[idx, 0 : len(sig.samples)] = np.array(sig.samples)
# --> 662 results_t, results_y = jit_sim_function(
#     663     unp.asarray(t_span),
#     664     unp.asarray(y0),
#     665     unp.asarray(all_samples),
#     666     unp.asarray(y0_input),
#     667     y0_cls,
#     668 )
#     669 results = OdeResult(t=results_t, y=results_y)
#     671 if y0_cls is not None and convert_results:
#
#     [... skipping hidden 1 frame]
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/pjit.py:341, in _cpp_pjit.<locals>.cache_miss(*args, **kwargs)
#     336 if config.no_tracing.value:
#     337   raise RuntimeError(f"re-tracing function {jit_info.fun_sourceinfo} for "
#     338                      "`jit`, but 'no_tracing' is set")
#     340 (outs, out_flat, out_tree, args_flat, jaxpr, attrs_tracked, executable,
# --> 341  pgle_profiler) = _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     343 maybe_fastpath_data = _get_fastpath_data(
#     344     executable, out_tree, args_flat, out_flat, attrs_tracked, jaxpr.effects,
#     345     jaxpr.consts, jit_info.abstracted_axes,
#     346     pgle_profiler)
#     348 return outs, maybe_fastpath_data, _need_to_rebuild_with_fdo(pgle_profiler)
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/pjit.py:195, in _python_pjit_helper(fun, jit_info, *args, **kwargs)
#     193   args_flat = map(core.full_lower, args_flat)
#     194   core.check_eval_args(args_flat)
# --> 195   out_flat, compiled, profiler = _pjit_call_impl_python(*args_flat, **p.params)
#     196 else:
#     197   out_flat = pjit_p.bind(*args_flat, **p.params)
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/pjit.py:1657, in _pjit_call_impl_python(jaxpr, in_shardings, out_shardings, in_layouts, out_layouts, resource_env, donated_invars, name, keep_unused, inline, compiler_options_kvs, *args)
#    1645 compiler_options_kvs = compiler_options_kvs + tuple(pgle_compile_options.items())
#    1646 # Passing mutable PGLE profile here since it should be extracted by JAXPR to
#    1647 # initialize the fdo_profile compile option.
#    1648 compiled = _resolve_and_lower(
#    1649     args, jaxpr=jaxpr, in_shardings=in_shardings,
#    1650     out_shardings=out_shardings, in_layouts=in_layouts,
#    1651     out_layouts=out_layouts, resource_env=resource_env,
#    1652     donated_invars=donated_invars, name=name, keep_unused=keep_unused,
#    1653     inline=inline, lowering_platforms=None,
#    1654     lowering_parameters=mlir.LoweringParameters(),
#    1655     pgle_profiler=pgle_profiler,
#    1656     compiler_options_kvs=compiler_options_kvs,
# -> 1657 ).compile()
#    1659 # This check is expensive so only do it if enable_checks is on.
#    1660 if compiled._auto_spmd_lowering and config.enable_checks.value:
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2446, in MeshComputation.compile(self, compiler_options)
#    2444 compiler_options_kvs = self._compiler_options_kvs + t_compiler_options
#    2445 if self._executable is None or compiler_options_kvs:
# -> 2446   executable = UnloadedMeshExecutable.from_hlo(
#    2447       self._name, self._hlo, **self.compile_args,
#    2448       compiler_options_kvs=compiler_options_kvs)
#    2449   if not compiler_options_kvs:
#    2450     self._executable = executable
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2959, in UnloadedMeshExecutable.from_hlo(***failed resolving arguments***)
#    2956       break
#    2958 util.test_event("pxla_cached_compilation")
# -> 2959 xla_executable = _cached_compilation(
#    2960     hlo, name, mesh, spmd_lowering,
#    2961     tuple_args, auto_spmd_lowering, allow_prop_to_inputs,
#    2962     allow_prop_to_outputs, tuple(host_callbacks), backend, da, pmap_nreps,
#    2963     compiler_options_kvs, pgle_profiler)
#    2965 orig_out_shardings = out_shardings
#    2967 if auto_spmd_lowering:
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/interpreters/pxla.py:2757, in _cached_compilation(computation, name, mesh, spmd_lowering, tuple_args, auto_spmd_lowering, allow_prop_to_inputs, allow_prop_to_outputs, host_callbacks, backend, da, pmap_nreps, compiler_options_kvs, pgle_profiler)
#    2749 compile_options = create_compile_options(
#    2750     computation, mesh, spmd_lowering, tuple_args, auto_spmd_lowering,
#    2751     allow_prop_to_inputs, allow_prop_to_outputs, backend,
#    2752     dev, pmap_nreps, compiler_options)
#    2754 with dispatch.log_elapsed_time(
#    2755     "Finished XLA compilation of {fun_name} in {elapsed_time:.9f} sec",
#    2756     fun_name=name, event=dispatch.BACKEND_COMPILE_EVENT):
# -> 2757   xla_executable = compiler.compile_or_get_cached(
#    2758       backend, computation, dev, compile_options, host_callbacks,
#    2759       pgle_profiler)
#    2760 return xla_executable
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/compiler.py:473, in compile_or_get_cached(backend, computation, devices, compile_options, host_callbacks, pgle_profiler)
#     471 else:
#     472   log_persistent_cache_miss(module_name, cache_key)
# --> 473   return _compile_and_write_cache(
#     474       backend,
#     475       computation,
#     476       compile_options,
#     477       host_callbacks,
#     478       module_name,
#     479       cache_key,
#     480   )
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/compiler.py:690, in _compile_and_write_cache(backend, computation, compile_options, host_callbacks, module_name, cache_key)
#     681 def _compile_and_write_cache(
#     682     backend: xc.Client,
#     683     computation: ir.Module,
#    (...)
#     687     cache_key: str,
#     688 ) -> xc.LoadedExecutable:
#     689   start_time = time.monotonic()
# --> 690   executable = backend_compile(
#     691       backend, computation, compile_options, host_callbacks
#     692   )
#     693   compile_time = time.monotonic() - start_time
#     694   _cache_write(
#     695       cache_key, compile_time, module_name, backend, executable, host_callbacks
#     696   )
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/profiler.py:334, in annotate_function.<locals>.wrapper(*args, **kwargs)
#     331 @wraps(func)
#     332 def wrapper(*args, **kwargs):
#     333   with TraceAnnotation(name, **decorator_kwargs):
# --> 334     return func(*args, **kwargs)
#     335   return wrapper
#
# File ~/virtualenvs/research_qiskit/lib/python3.12/site-packages/jax/_src/compiler.py:324, in backend_compile(backend, module, options, host_callbacks)
#     318     return backend.compile(
#     319         built_c, compile_options=options, host_callbacks=host_callbacks
#     320     )
#     321   # Some backends don't have `host_callbacks` option yet
#     322   # TODO(sharadmv): remove this fallback when all backends allow `compile`
#     323   # to take in `host_callbacks`
# --> 324   return backend.compile(built_c, compile_options=options)
#     325 except xc.XlaRuntimeError as e:
#     326   for error_handler in _XLA_RUNTIME_ERROR_HANDLERS:
#
# KeyboardInterrupt:

# %%
pop_values_absorb = [[[] for i in range(9)] for i in range(9)]
basis_states = ['00','01','02','10','11','12','20','21','22']

for j, item in enumerate(freq_absorb_jobs_ef):
    for res in item:
        for i in basis_states:
            if i in res.result().get_counts():
                pop_values_absorb[int(i, 3)].append(res.result().get_counts()[i]/1024)
            else:
                pop_values_absorb[int(i, 3)].append(0)

# %% [markdown]
# ### Checking the effects of duration in the cross resonance when the CR frequency is set as freq_1

# %% [markdown]
# ### Setting control qubit in the state $|0\rangle$

# %%
min_duration = 500
max_duration = 4000
steps = 100

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))

def get_cr_pulse():
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(640, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array_0_dur = []
for dur in np.linspace(min_duration, max_duration, steps):
    cr_pulse = get_cr_pulse()
    
    cr_pulse.assign_parameters({'duration': int(dur)})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array_0_dur.append(cr_job)
# Out:
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# ...
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/3556926420.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/3556926420.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/3556926420.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/3556926420.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(640, uchan0)
# /tmp/ipykernel_403/3556926420.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/3556926420.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/3556926420.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/3556926420.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))

# %%
cr_0_prob_dur = [[],[],[]]

counts = 0
tot_counts = 0
for res in cr_job_array_0_dur:
    for i in range(3):
        if '0'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['0'+str(i)]
        else:
            counts = 0
        cr_0_prob_dur[i].append(counts)
    tot_counts = cr_0_prob_dur[0][-1] + cr_0_prob_dur[1][-1] + cr_0_prob_dur[2][-1]
    for i in range(3):
        cr_0_prob_dur[i][-1] = cr_0_prob_dur[i][-1]/tot_counts
#         cr_0_prob_dur[i][-1] = cr_0_prob_dur[i][-1]/1024

# %%
dur_list = np.linspace(min_duration, max_duration, steps)
plt.plot(dur_list, cr_0_prob_dur[0], color='r')
plt.plot(dur_list, cr_0_prob_dur[1], color='b')
plt.plot(dur_list, cr_0_prob_dur[2], color='g')

# %% [markdown]
# ### Setting control qubit in the state $|1\rangle$

# %%
min_duration = 100
max_duration = 4000
steps = 50

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))


def get_cr_pulse():
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array_1_dur = []
for dur in np.linspace(min_duration, max_duration, steps):
    cr_pulse = get_cr_pulse()
    
    cr_pulse.assign_parameters({'duration': int(dur)})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array_1_dur.append(cr_job)
# Out:
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
# ...
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4129773901.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4129773901.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4129773901.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4129773901.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0), dchan1)
# /tmp/ipykernel_403/4129773901.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4129773901.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4129773901.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4129773901.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4129773901.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4129773901.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))

# %%
cr_1_prob_dur = [[],[], []]

counts = 0
tot_counts = 0
for res in cr_job_array_1_dur:
    for i in range(3):
        if '1'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['1'+str(i)]
        else:
            counts = 0
        cr_1_prob_dur[i].append(counts)
    tot_counts = cr_1_prob_dur[0][-1] + cr_1_prob_dur[1][-1] + cr_1_prob_dur[2][-1]
    for i in range(3):
        cr_1_prob_dur[i][-1] = cr_1_prob_dur[i][-1]/tot_counts
#         cr_1_prob_dur[i][-1] = cr_1_prob_dur[i][-1]/1024

# %%
dur_list = np.linspace(min_duration, max_duration, steps)
plt.plot(dur_list, cr_1_prob_dur[0], color='r')
plt.plot(dur_list, cr_1_prob_dur[1], color='b')
plt.plot(dur_list, cr_1_prob_dur[2], color='g')

# %% [markdown]
# ### Setting control qubit in the state $|2\rangle$

# %%
min_duration = 100
max_duration = 4000
steps = 50

theta_1 = 2*np.acos(np.sqrt(1/3))
theta_2 = 2*np.acos(np.sqrt(1/2))


def get_cr_pulse():
    dur = Parameter('duration')
    tot_time = dur + 640
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        pulse.set_frequency(ef_freq_0, dchan0)
        pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
        pulse.set_frequency(freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
        pulse.set_frequency(ef_freq_1, dchan1)
        pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
        pulse.set_frequency(ef_freq_1, uchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array_2_dur = []
for dur in np.linspace(min_duration, max_duration, steps):
    cr_pulse = get_cr_pulse()
    
    cr_pulse.assign_parameters({'duration': int(dur)})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array_2_dur.append(cr_job)
# Out:
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# ...
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_403/4159469828.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:15: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_0, dchan0)
# /tmp/ipykernel_403/4159469828.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, ef_amp_0, 80, beta_0, limit_amplitude=False), dchan0)
# /tmp/ipykernel_403/4159469828.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, dchan1)
# /tmp/ipykernel_403/4159469828.py:20: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_2/np.pi)*ef_amp_1, 80, beta_0, limit_amplitude=False), dchan1)
# /tmp/ipykernel_403/4159469828.py:21: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(ef_freq_1, uchan0)
# /tmp/ipykernel_403/4159469828.py:22: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_403/4159469828.py:23: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, 43.65, 76, 0.841*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_403/4159469828.py:24: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_403/4159469828.py:25: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:26: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_403/4159469828.py:27: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))

# %%
cr_2_prob_dur = [[],[], []]

counts = 0
tot_counts = 0
for res in cr_job_array_2_dur:
    for i in range(3):
        if '1'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['1'+str(i)]
        else:
            counts = 0
        cr_2_prob_dur[i].append(counts)
    tot_counts = cr_2_prob_dur[0][-1] + cr_2_prob_dur[1][-1] + cr_2_prob_dur[2][-1]
    for i in range(3):
        cr_2_prob_dur[i][-1] = cr_2_prob_dur[i][-1]/tot_counts
#         cr_2_prob_dur[i][-1] = cr_2_prob_dur[i][-1]/1024

# %%
dur_list = np.linspace(min_duration, max_duration, steps)
plt.plot(dur_list, cr_2_prob_dur[0], color='r')
plt.plot(dur_list, cr_2_prob_dur[1], color='b')
plt.plot(dur_list, cr_2_prob_dur[2], color='g')

# %% [markdown]
# ### Checking the effects of amplitude in the cross resonance when freq is set to freq_1

# %% [markdown]
# ### Setting control qubit in the state $|0\rangle$

# %%
min_amp = 0
max_amp = 4
steps = 100

def get_cr_pulse(amp):
#     dur = Parameter('duration')
    dur = 1500
    tot_time = dur + 320
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
        pulse.set_frequency(freq_1, uchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
#         pulse.play(pulse.Gaussian(750, amp, 64), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array_0_amp = []
for amp in np.linspace(min_amp, max_amp, steps):
    cr_pulse = get_cr_pulse(amp)
    
#     cr_pulse.assign_parameters({'duration': int(dur)})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array_0_amp.append(cr_job)
# Out:
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# ...
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/1688985553.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/1688985553.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, 0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/1688985553.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/1688985553.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/1688985553.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/1688985553.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/1688985553.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/1688985553.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))

# %%
cr_0_prob_amp = [[],[],[]]

counts = 0
for res in cr_job_array_0_amp:
    for i in range(3):
        if '0'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['0'+str(i)]
        else:
            counts = 0
        cr_0_prob_amp[i].append(counts/1024.)


# for res in cr_job_array_0:
#     for i in range(3):
#         counts = 0
#         for item in res.result().get_counts():
#             if item[-1] == str(i):
#                 counts += res.result().get_counts()[item]
#         cr_0_prob[i].append(counts/1024.)

# %%
# for res in cr_job_array_0:
#     print(res.result().get_counts())

# %%
amp_list = np.linspace(min_amp, max_amp, steps)
plt.plot(amp_list, cr_0_prob_amp[0], color='r')
plt.plot(amp_list, cr_0_prob_amp[1], color='b')

# %%
print(amp_list[np.where(cr_0_prob[1] == max(cr_0_prob[1]))[0]])
# Out:
# [0.92929293]

# %%
opt_cr_amp_1 = 0.92929293

# %% [markdown]
# ### Setting control qubit in the state $|1\rangle$

# %%
min_amp = 0
max_amp = 4
steps = 100

def get_cr_pulse(amp):
#     dur = Parameter('duration')
    dur = 1500
    tot_time = dur + 320
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
        pulse.set_frequency(freq_1, uchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
#         pulse.play(pulse.Gaussian(750, amp, 64), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array_1_amp = []
for amp in np.linspace(min_amp, max_amp, steps):
    cr_pulse = get_cr_pulse(amp)
    
#     cr_pulse.assign_parameters({'duration': int(dur)})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array_1_amp.append(cr_job)
# Out:
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# ...
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:9: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as cr_pulse:
# /tmp/ipykernel_64641/4195151826.py:10: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_64641/4195151826.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_64641/4195151826.py:12: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_1, uchan0)
# /tmp/ipykernel_64641/4195151826.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_64641/4195151826.py:14: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
# /tmp/ipykernel_64641/4195151826.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan0)
# /tmp/ipykernel_64641/4195151826.py:17: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(tot_time, achan1)
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:18: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan0, pulse.MemorySlot(1))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The class ``qiskit.pulse.channels.Channel`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))
# /tmp/ipykernel_64641/4195151826.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.acquire()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.acquire(1, achan1, pulse.MemorySlot(0))

# %%
cr_1_prob_amp = [[],[]]

counts = 0
for res in cr_job_array_1_amp:
    for i in range(2):
        if '1'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['1'+str(i)]
        else:
            counts = 0
        cr_1_prob_amp[i].append(counts/1024.)

# for res in cr_job_array_1:
#     for i in range(2):
#         counts = 0
#         for item in res.result().get_counts():
#             if item[-1] == str(i):
#                 counts += res.result().get_counts()[item]
#         cr_1_prob[i].append(counts/1024.)

# %%
# for res in cr_job_array:
#     print(res.result().get_counts())

# %%
amp_list = np.linspace(min_amp, max_amp, steps)
plt.plot(amp_list, cr_1_prob_amp[0], color='r')
plt.plot(amp_list, cr_1_prob_amp[1], color='b')

# %%
print(amp_list[np.where(cr_1_prob[1] == max(cr_1_prob[1]))[0]])
# Out:
# [0.92929293]

# %% [markdown]
# ### Checking the effects of width in the cross resonance

# %% [markdown]
# ### Setting the control qubit to the state $|0\rangle$

# %%
min_scale = 0.7
max_scale = 1
steps = 50

def get_cr_pulse():
    dur = int(1500)
    scale = Parameter('scale')
    tot_time = dur + 320
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Gaussian(320, 0, 80), dchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 1, 0.05*dur, scale*dur), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array = []
for scale in np.linspace(min_scale, max_scale, steps):
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'scale': scale})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array.append(cr_job)

# %%
for res in cr_job_array:
    print(res.result().get_counts())

# %%
cr_0_prob = [[],[],[]]

counts = 0
for res in cr_job_array:
    for i in range(3):
        if '0'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['0'+str(i)]
        else:
            counts = 0
        cr_0_prob[i].append(counts/1024.)

# %%
scale_list = np.linspace(min_scale, max_scale, steps)
plt.plot(scale_list, cr_0_prob[0], color='r')
plt.plot(scale_list, cr_0_prob[1], color='b')
plt.plot(scale_list, cr_0_prob[2], color='g')

# %% [markdown]
# ### Setting the control qubit to the state $|1\rangle$

# %%
min_scale = 0.9
max_scale = 1
steps = 50

def get_cr_pulse():
    dur = int(1500)
    scale = Parameter('scale')
    tot_time = dur + 320
    with pulse.build(name="cr_0") as cr_pulse:
        pulse.set_frequency(freq_0, dchan0)
        pulse.play(pulse.Gaussian(320, amp_0, 80), dchan0)
        pulse.delay(320, uchan0)
        pulse.play(pulse.GaussianSquare(dur, 1, 0.05*dur, scale*dur), uchan0)
        pulse.delay(tot_time, achan0)
        pulse.delay(tot_time, achan1)
        pulse.acquire(1, achan0, pulse.MemorySlot(1))
        pulse.acquire(1, achan1, pulse.MemorySlot(0))
    return cr_pulse

cr_job_array = []
for scale in np.linspace(min_scale, max_scale, steps):
    cr_pulse = get_cr_pulse()

    cr_pulse.assign_parameters({'scale': scale})
    cr_job = backend.run(cr_pulse, meas_level=2, max_outcome_level=2)
    cr_job_array.append(cr_job)

# %%
for res in cr_job_array:
    print(res.result().get_counts())

# %%
cr_1_prob = [[],[],[]]

counts = 0
for res in cr_job_array:
    for i in range(3):
        if '1'+str(i) in res.result().get_counts():
            counts = res.result().get_counts()['1'+str(i)]
        else:
            counts = 0
        cr_1_prob[i].append(counts/1024.)

# %%
scale_list = np.linspace(min_scale, max_scale, steps)
plt.plot(scale_list, cr_1_prob[0], color='r')
plt.plot(scale_list, cr_1_prob[1], color='b')
plt.plot(scale_list, cr_1_prob[2], color='g')

# %% [markdown]
# ## Calculating concurrence as provided in Gambetta's paper
#
# 1. First set the state to $(|00\rangle + |10\rangle)/\sqrt{2}$.
# 2. Apply the CR pulse over varied times and see how the value of the concurrence changes over time

# %%
dt = 1/4.5e9

# %%
def qubit_concur(state):
    rho = DensityMatrix(state).data
    yy_mat = np.fliplr(np.diag([-1, 1, 1, -1]))
    sigma = rho.dot(yy_mat).dot(rho.conj()).dot(yy_mat)
    w = np.sort(np.real(la.eigvals(sigma)))
    w = np.sqrt(np.maximum(w, 0.0))
    
    return max(0.0, w[-1] - np.sum(w[0:-1]))

# %%
from qiskit.quantum_info.states import Statevector
from qiskit.quantum_info import *
import scipy.linalg as la

def get_bell_pulse(theta_1, freq, amp):
    dur = Parameter('dur')
    with pulse.build(name="cr_0") as super_pulse:
        pulse.set_frequency(freq_0, dchan0)
        
        # Applying a pulse to excite the state of the first qutrit to (|0> + |1>)/sqrt(2)
        pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_0, 80, beta_0), dchan0)
        
        pulse.set_frequency(freq, uchan0)

#         # Delaying the signal in the control channel by 640 units
        pulse.delay(320, uchan0)
        
#         # Applying the cross resonance pulse on the control channel of first qubit
        pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)
        
    return super_pulse

min_dur = 100
max_dur = 4000
steps = 50

concur_array = [[],[],[],[]]
amp_list = [1, 1.5, 2, 2.5]
# amp_list = [2.5]

for i, amp in enumerate(amp_list):
    for dur in np.linspace(min_dur, max_dur, steps):
        theta_1 = 2*np.acos(np.sqrt(1/2))
        test_cr_pulse = get_bell_pulse(theta_1, freq_1, amp)
        test_cr_pulse.assign_parameters({'dur': int(dur)})
        y0 = Statevector([1,0,0,0])
        cr_job = backend.solve(test_cr_pulse, [0, (dur+320)*dt], y0)

        t_state = cr_job[0].y[-1]
        concur_array[i].append(qubit_concur(t_state))
    #     print(np.round(t_state.probabilities(), 4))
    #     print('Concurrence : ', qubit_concur(t_state))
# Out:
# /tmp/ipykernel_71967/2232216410.py:7: DeprecationWarning: The function ``qiskit.pulse.builder.build()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   with pulse.build(name="cr_0") as super_pulse:
# /tmp/ipykernel_71967/2232216410.py:8: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq_0, dchan0)
# /tmp/ipykernel_71967/2232216410.py:11: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.Drag(320, (theta_1/np.pi)*amp_0, 80, beta_0), dchan0)
# /tmp/ipykernel_71967/2232216410.py:13: DeprecationWarning: The function ``qiskit.pulse.builder.set_frequency()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.set_frequency(freq, uchan0)
# /tmp/ipykernel_71967/2232216410.py:16: DeprecationWarning: The function ``qiskit.pulse.builder.delay()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.delay(320, uchan0)
# /tmp/ipykernel_71967/2232216410.py:19: DeprecationWarning: The function ``qiskit.pulse.builder.play()`` is deprecated as of Qiskit 1.3. It will be removed in Qiskit 2.0. The entire Qiskit Pulse package is being deprecated and will be moved to the Qiskit Dynamics repository: https://github.com/qiskit-community/qiskit-dynamics
#   pulse.play(pulse.GaussianSquare(dur, amp, 64, 0.8*dur, limit_amplitude=False), uchan0)

# %%
dur_list = np.linspace(min_dur, max_dur, steps)

plt.plot(dur_list, concur_array[0], color='r')
plt.plot(dur_list, concur_array[1], color='b')
plt.plot(dur_list, concur_array[2], color='g')
plt.plot(dur_list, concur_array[3], color='y')
